# %%
# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud

import ipynb
from ipynb.fs.full.Statistical_Analysis import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sadik\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sadik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
Download_df
# Out:
#       Unnamed: 0     video_id      channelTitle  \
# 0              0  HZ8uXq5VG2w     Corey Schafer
# 1              1  vQQEaSnQ_bs     Corey Schafer
# 2              2  1KO_HZtHOWI     Corey Schafer
# 3              3  coZbOM6E47I     Corey Schafer
# 4              4  th5_9woFJmk     Corey Schafer
# ...          ...          ...               ...
# 2256        2256  4rfr6A3lO-Y  Alex The Analyst
# 2257        2257  OTq2NRy_AGs  Alex The Analyst
# 2258        2258  ya28cb3zFGE  Alex The Analyst
# 2259        2259  Hsi2BG0SOiQ  Alex The Analyst
# 2260        2260  6lQzbk6_OTw  Alex The Analyst
#
#                                                   title  \
# 0     Python Tutorial: Simulate the Powerball Lotter...
# 1     Python YouTube API Tutorial: Using OAuth to Ac...
# 2     Python YouTube API Tutorial: Sort a Playlist b...
# 3     Python YouTube API Tutorial: Calculating the D...
# 4     Python YouTube API Tutorial: Getting Started -...
# ...                                                 ...
# 2256  Data Analyst Resume | Reviewing My Resume! | F...
# 2257  Working at a Big Company Vs Small Company | To...
# 2258      Data Analyst Salary | 100k with No Experience
# 2259  Truth About Big Companies | Told by a Fortune ...
# 2260                  Top 3 Data Analyst Skills in 2020
#
#                                             description  \
# 0     In this Python Programming video, we will be l...
# 1     In this Python Programming Tutorial, we'll be ...
# 2     In this Python Programming Tutorial, we'll be ...
# 3     In this Python Programming Tutorial, we'll be ...
# 4     In this Python Programming Tutorial, we'll be ...
# ...                                                 ...
# 2256  Data Analyst Resume | Reviewing My Resume! | F...
# 2257  Working at a Big Company Vs Small Company | To...
# 2258  Data Analyst Salary | 100k with No Experience ...
# 2259  Truth About Big Companies // There are a ton o...
# 2260  Top 3 Data Analyst Skills in 2020 // There are...
#
#                                                    tags  \
# 0     ['python', 'lottery', 'powerball', 'simulation...
# 1     ['python', 'youtube api', 'youtube-api', 'yout...
# 2     ['python', 'youtube api', 'youtube-api', 'yout...
# 3     ['python', 'youtube api', 'youtube-api', 'pyth...
# 4     ['python', 'youtube api', 'youtube-api', 'pyth...
# ...                                                 ...
# 2256  ['Data Analyst', 'How to become a data analyst...
# 2257  ['Data Analyst', 'How to become a Data Analyst...
# 2258  ['Data Analyst Salary', 'Data analyst with no ...
# 2259  ['Working at a big company', 'Big company data...
# 2260  ['Top skills for data analyst', 'Top 3 skills ...
#
#                    publishedAt  viewCount  likeCount  favouriteCount  \
# 0    2023-01-09 18:45:00+00:00    97159.0     3556.0             NaN
# 1    2020-09-10 14:15:03+00:00   126313.0     2499.0             NaN
# 2    2020-07-31 14:30:00+00:00    42125.0     1068.0             NaN
# 3    2020-06-10 15:53:26+00:00    50392.0     1509.0             NaN
# 4    2020-05-29 16:17:07+00:00   174024.0     5199.0             NaN
# ...                        ...        ...        ...             ...
# 2256 2020-01-30 14:07:55+00:00    60275.0     1476.0             NaN
# 2257 2020-01-25 16:38:39+00:00    13253.0      366.0             NaN
# 2258 2020-01-23 03:16:09+00:00    56732.0     2004.0             NaN
# 2259 2020-01-21 03:52:15+00:00     7048.0      269.0             NaN
# 2260 2020-01-17 14:31:39+00:00    25781.0     1282.0             NaN
#
#       commentCount  duration definition  caption publishDayName  durationSecs  \
# 0            768.0  PT38M56S         hd    False         Monday        2336.0
# 1            353.0  PT43M21S         hd    False       Thursday        2601.0
# 2            128.0   PT22M8S         hd    False         Friday        1328.0
# 3            179.0  PT37M38S         hd    False      Wednesday        2258.0
# 4            324.0  PT20M49S         hd    False         Friday        1249.0
# ...            ...       ...        ...      ...            ...           ...
# 2256          64.0   PT7M33S         hd    False       Thursday         453.0
# 2257          21.0   PT5M50S         hd    False       Saturday         350.0
# 2258         224.0    PT5M3S         hd    False       Thursday         303.0
# 2259          17.0   PT5M45S         hd    False        Tuesday         345.0
# 2260         137.0   PT2M40S         hd    False         Friday         160.0
#
#       tagCount  likeRatio  commentRatio  titleLength
# 0          241  36.599800      7.904569           60
# 1          276  19.784187      2.794645           64
# 2          407  25.353116      3.038576           67
# 3          479  29.945229      3.552151           67
# 4          370  29.875190      1.861812           87
# ...        ...        ...           ...          ...
# 2256       386  24.487764      1.061800           69
# 2257       425  27.616389      1.584547           78
# 2258       392  35.323979      3.948389           45
# 2259       204  38.166856      2.412032           62
# 2260       231  49.726543      5.313991           33
#
# [2261 rows x 20 columns]

# %%
# Best Performing Videos

ax = sns.barplot(x = 'title', y = 'viewCount', data = Download_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %%
# Worst Performing Videos


ax = sns.barplot(x = 'title', y = 'viewCount', data = Download_df.sort_values('viewCount', ascending=True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))
# Out:
# C:\Users\sadik\anaconda3\envs\data-mining-project\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128013 (\N{SNAKE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sadik\anaconda3\envs\data-mining-project\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128104 (\N{MAN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sadik\anaconda3\envs\data-mining-project\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127996 (\N{EMOJI MODIFIER FITZPATRICK TYPE-3}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sadik\anaconda3\envs\data-mining-project\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128187 (\N{PERSONAL COMPUTER}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sadik\anaconda3\envs\data-mining-project\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\sadik\anaconda3\envs\data-mining-project\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128013 (\N{SNAKE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sadik\anaconda3\envs\data-mining-project\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128104 (\N{MAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sadik\anaconda3\envs\data-mining-project\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127996 (\N{EMOJI MODIFIER FITZPATRICK TYPE-3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sadik\anaconda3\envs\data-mining-project\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128187 (\N{PERSONAL COMPUTER}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sadik\anaconda3\envs\data-mining-project\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.violinplot(x=Download_df['channelTitle'], y=Download_df['viewCount'])
# Out:
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %%
# Views Vs Likes and comments

fig, ax = plt.subplots(1,2)
sns.scatterplot(data = Download_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = Download_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %%
# Video Duration

sns.histplot(data = Download_df, x = 'durationSecs', bins=30)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %%
# Wordcloud for video titles

stop_words = set(stopwords.words('english'))
Download_df['title_no_stopwords'] = Download_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in Download_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words)

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud)
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black',
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %%
# Upload Schedule

day_df = pd.DataFrame(Download_df['publishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='publishDayName', rot=0)

# %%
Download_df
# Out:
#       Unnamed: 0     video_id      channelTitle  \
# 0              0  HZ8uXq5VG2w     Corey Schafer
# 1              1  vQQEaSnQ_bs     Corey Schafer
# 2              2  1KO_HZtHOWI     Corey Schafer
# 3              3  coZbOM6E47I     Corey Schafer
# 4              4  th5_9woFJmk     Corey Schafer
# ...          ...          ...               ...
# 2256        2256  4rfr6A3lO-Y  Alex The Analyst
# 2257        2257  OTq2NRy_AGs  Alex The Analyst
# 2258        2258  ya28cb3zFGE  Alex The Analyst
# 2259        2259  Hsi2BG0SOiQ  Alex The Analyst
# 2260        2260  6lQzbk6_OTw  Alex The Analyst
#
#                                                   title  \
# 0     Python Tutorial: Simulate the Powerball Lotter...
# 1     Python YouTube API Tutorial: Using OAuth to Ac...
# 2     Python YouTube API Tutorial: Sort a Playlist b...
# 3     Python YouTube API Tutorial: Calculating the D...
# 4     Python YouTube API Tutorial: Getting Started -...
# ...                                                 ...
# 2256  Data Analyst Resume | Reviewing My Resume! | F...
# 2257  Working at a Big Company Vs Small Company | To...
# 2258      Data Analyst Salary | 100k with No Experience
# 2259  Truth About Big Companies | Told by a Fortune ...
# 2260                  Top 3 Data Analyst Skills in 2020
#
#                                             description  \
# 0     In this Python Programming video, we will be l...
# 1     In this Python Programming Tutorial, we'll be ...
# 2     In this Python Programming Tutorial, we'll be ...
# 3     In this Python Programming Tutorial, we'll be ...
# 4     In this Python Programming Tutorial, we'll be ...
# ...                                                 ...
# 2256  Data Analyst Resume | Reviewing My Resume! | F...
# 2257  Working at a Big Company Vs Small Company | To...
# 2258  Data Analyst Salary | 100k with No Experience ...
# 2259  Truth About Big Companies // There are a ton o...
# 2260  Top 3 Data Analyst Skills in 2020 // There are...
#
#                                                    tags  \
# 0     ['python', 'lottery', 'powerball', 'simulation...
# 1     ['python', 'youtube api', 'youtube-api', 'yout...
# 2     ['python', 'youtube api', 'youtube-api', 'yout...
# 3     ['python', 'youtube api', 'youtube-api', 'pyth...
# 4     ['python', 'youtube api', 'youtube-api', 'pyth...
# ...                                                 ...
# 2256  ['Data Analyst', 'How to become a data analyst...
# 2257  ['Data Analyst', 'How to become a Data Analyst...
# 2258  ['Data Analyst Salary', 'Data analyst with no ...
# 2259  ['Working at a big company', 'Big company data...
# 2260  ['Top skills for data analyst', 'Top 3 skills ...
#
#                    publishedAt  viewCount  likeCount  favouriteCount  ...  \
# 0    2023-01-09 18:45:00+00:00    97159.0     3556.0             NaN  ...
# 1    2020-09-10 14:15:03+00:00   126313.0     2499.0             NaN  ...
# 2    2020-07-31 14:30:00+00:00    42125.0     1068.0             NaN  ...
# 3    2020-06-10 15:53:26+00:00    50392.0     1509.0             NaN  ...
# 4    2020-05-29 16:17:07+00:00   174024.0     5199.0             NaN  ...
# ...                        ...        ...        ...             ...  ...
# 2256 2020-01-30 14:07:55+00:00    60275.0     1476.0             NaN  ...
# 2257 2020-01-25 16:38:39+00:00    13253.0      366.0             NaN  ...
# 2258 2020-01-23 03:16:09+00:00    56732.0     2004.0             NaN  ...
# 2259 2020-01-21 03:52:15+00:00     7048.0      269.0             NaN  ...
# 2260 2020-01-17 14:31:39+00:00    25781.0     1282.0             NaN  ...
#
#       duration definition caption  publishDayName durationSecs  tagCount  \
# 0     PT38M56S         hd   False          Monday       2336.0       241
# 1     PT43M21S         hd   False        Thursday       2601.0       276
# 2      PT22M8S         hd   False          Friday       1328.0       407
# 3     PT37M38S         hd   False       Wednesday       2258.0       479
# 4     PT20M49S         hd   False          Friday       1249.0       370
# ...        ...        ...     ...             ...          ...       ...
# 2256   PT7M33S         hd   False        Thursday        453.0       386
# 2257   PT5M50S         hd   False        Saturday        350.0       425
# 2258    PT5M3S         hd   False        Thursday        303.0       392
# 2259   PT5M45S         hd   False         Tuesday        345.0       204
# 2260   PT2M40S         hd   False          Friday        160.0       231
#
#       likeRatio  commentRatio  titleLength  \
# 0     36.599800      7.904569           60
# 1     19.784187      2.794645           64
# 2     25.353116      3.038576           67
# 3     29.945229      3.552151           67
# 4     29.875190      1.861812           87
# ...         ...           ...          ...
# 2256  24.487764      1.061800           69
# 2257  27.616389      1.584547           78
# 2258  35.323979      3.948389           45
# 2259  38.166856      2.412032           62
# 2260  49.726543      5.313991           33
#
#                                      title_no_stopwords
# 0     [Python, Tutorial:, Simulate, Powerball, Lotte...
# 1     [Python, YouTube, API, Tutorial:, Using, OAuth...
# 2     [Python, YouTube, API, Tutorial:, Sort, Playli...
# 3     [Python, YouTube, API, Tutorial:, Calculating,...
# 4     [Python, YouTube, API, Tutorial:, Getting, Sta...
# ...                                                 ...
# 2256  [Data, Analyst, Resume, |, Reviewing, My, Resu...
# 2257  [Working, Big, Company, Vs, Small, Company, |,...
# 2258   [Data, Analyst, Salary, |, 100k, No, Experience]
# 2259  [Truth, About, Big, Companies, |, Told, Fortun...
# 2260              [Top, 3, Data, Analyst, Skills, 2020]
#
# [2261 rows x 21 columns]
